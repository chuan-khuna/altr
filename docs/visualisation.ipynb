# %%
from altr.visualisation import set_style, set_seaborn_palette
from altr import visualisation as altr_vis

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import patheffects

# %%
altr_vis.available_palettes
# Out:
# ['economist', 'ft', 'london_dark', 'nzk', 'economist_graphic']

# %%
altr_vis.available_styles
# Out:
# ['economist', 'nzk', 'london_dark', 'ft', 'economist_graphic']

# %% [markdown]
# generate mock data

# %%
n = 100
num_series = 5

df = pd.DataFrame(
    np.random.randn(n, num_series),
    index=np.arange(n),
    columns=[f'fake {i + 1}' for i in range(num_series)],
)

df = df.cumsum()

df
# Out:
#       fake 1    fake 2     fake 3    fake 4    fake 5
# 0  -0.912309  1.547426  -0.314694 -0.428853  0.159777
# 1  -0.739062  2.415404   0.689536  0.235081  0.900157
# 2  -0.675601  1.304700   0.325798  0.299156  3.928081
# 3  -0.245242  0.914581   1.459117  0.596118  2.975688
# 4   1.614582  0.619255   0.518397  2.090037  2.983794
# ..       ...       ...        ...       ...       ...
# 95  6.470086 -3.148100  17.706458 -3.400735  0.056410
# 96  6.366286 -1.695682  19.511167 -2.753168 -0.241571
# 97  6.624876 -0.952576  18.732880 -2.847403  1.250475
# 98  5.021571 -0.634281  17.906194 -3.991686  3.126814
# 99  7.408997 -0.676180  17.610577 -4.361347  3.397209
#
# [100 rows x 5 columns]

# %%
figsize = (8, 4)

for style in altr_vis.available_styles:
    set_style(style)
    set_seaborn_palette(style)

    fig = plt.figure(figsize=figsize, dpi=100)

    for col in df.columns:
        sns.lineplot(
            x=df.index,
            y=df[col],
            path_effects=[patheffects.withStroke(linewidth=3, foreground="#F2DFCE")],
        )

    plt.title(style)
    plt.xlabel('')
    plt.ylabel('')
    plt.show()

# %%
set_style('ft')
set_seaborn_palette('ft', 'vis_colors')

fig = plt.figure(figsize=figsize, dpi=100)

for col in df.columns:
    sns.lineplot(
        x=df.index,
        y=df[col],
        path_effects=[patheffects.withStroke(linewidth=3, foreground="#F2DFCE")],
    )

plt.title('ft')
plt.xlabel('')
plt.ylabel('')
plt.show()

# %%
set_style('ft')
set_seaborn_palette('ft', 'main_colors')

fig = plt.figure(figsize=figsize, dpi=100)

for col in df.columns:
    sns.lineplot(
        x=df.index,
        y=df[col],
        path_effects=[patheffects.withStroke(linewidth=3, foreground="#F2DFCE")],
    )

plt.title('ft')
plt.xlabel('')
plt.ylabel('')
plt.show()
