# %%
from altr.visualisation import set_style, set_seaborn_palette
from altr import visualisation as altr_vis

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import patheffects

# %%
altr_vis.available_palettes
# Out:
# ['economist', 'ft', 'london_dark', 'nzk', 'economist_graphic']

# %%
altr_vis.available_styles
# Out:
# ['economist', 'nzk', 'london_dark', 'ft', 'economist_graphic']

# %% [markdown]
# generate mock data

# %%
n = 100
num_series = 5

df = pd.DataFrame(
    np.random.randn(n, num_series),
    index=np.arange(n),
    columns=[f'fake {i + 1}' for i in range(num_series)],
)

df = df.cumsum()

df
# Out:
#       fake 1    fake 2    fake 3     fake 4     fake 5
# 0  -0.702899 -0.343487  0.712636   1.411382   2.872610
# 1  -1.565088  1.308533  3.512013   1.038269   2.249439
# 2  -1.493126  0.761160  2.566015   0.147864   2.448857
# 3  -0.175552  0.233215  1.519304   0.713289   3.062513
# 4  -0.844253 -0.364990  2.705181   0.723492   1.376769
# ..       ...       ...       ...        ...        ...
# 95 -4.836086  5.662797  3.991726  10.602681 -27.526702
# 96 -4.439126  4.409460  5.153716  10.534985 -25.904595
# 97 -5.773921  4.057822  3.064392  10.594300 -26.945899
# 98 -6.719746  4.382213  4.405395  10.236344 -26.892064
# 99 -6.135956  3.917454  4.881453   9.540467 -27.548642
#
# [100 rows x 5 columns]

# %%
figsize = (8, 4)

for style in altr_vis.available_styles:
    set_style(style)
    set_seaborn_palette(style)

    fig = plt.figure(figsize=figsize, dpi=100)

    for col in df.columns:
        sns.lineplot(
            x=df.index,
            y=df[col],
            path_effects=[patheffects.withStroke(linewidth=3, foreground="#F2DFCE")],
        )

    plt.title(style)
    plt.xlabel('')
    plt.ylabel('')
    plt.show()

# %%
set_style('ft')
set_seaborn_palette('ft', 'vis_colors')

fig = plt.figure(figsize=figsize, dpi=100)

for col in df.columns:
    sns.lineplot(
        x=df.index,
        y=df[col],
        path_effects=[patheffects.withStroke(linewidth=3, foreground="#F2DFCE")],
    )

plt.title('ft')
plt.xlabel('')
plt.ylabel('')
plt.show()

# %%
set_style('ft')
set_seaborn_palette('ft', 'main_colors')

fig = plt.figure(figsize=figsize, dpi=100)

for col in df.columns:
    sns.lineplot(
        x=df.index,
        y=df[col],
        path_effects=[patheffects.withStroke(linewidth=3, foreground="#F2DFCE")],
    )

plt.title('ft')
plt.xlabel('')
plt.ylabel('')
plt.show()
